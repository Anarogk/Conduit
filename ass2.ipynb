# %%
import tensorflow as tf
from tensorflow import keras

############################################

import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd 
import random
# %matplotlib inline 


#############################################

#load the dataset from the mnist and traiin_test split ( modified national institute of standards and technology dataset )
mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()

##############################################

# see how first image looks 
plt.matshow(x_train[0])

##############################################

plt.matshow(x_train[60])

##############################################

# normalixe the pixels of the images by scalin it to the range (0-1) 
x_train= x_train/255
x_test = x_test/255

##############################################

# building the model
model=keras.Sequential([
keras.layers.Flatten(input_shape=(28,28)),
keras.layers.Dense(128,activation='relu'),
keras.layers.Dense(10,activation='softmax') 
])

###############################################

model.summary()

###############################################

model.compile(optimizer='SGD',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

################################################

history= model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10)

################################################

n=random.randint(0,9999)
plt.imshow(x_test[n])
plt.show

################################################

test_loss,test_acc= model.evaluate(x_test,y_test)
print("loss=%.3f"%test_loss)
print("Accuracy=%.3f"%test_acc)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6390 - accuracy: 0.8393 - val_loss: 0.3524 - val_accuracy: 0.9039
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3298 - accuracy: 0.9073 - val_loss: 0.2863 - val_accuracy: 0.9198
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2818 - accuracy: 0.9193 - val_loss: 0.2547 - val_accuracy: 0.9296
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2521 - accuracy: 0.9287 - val_loss: 0.2333 - val_accuracy: 0.9348
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2299 - accuracy: 0.9353 - val_loss: 0.2178 - val_accuracy: 0.9385
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2120 - accuracy: 0.9402 - val_loss: 0.2005 - val_accuracy: 0.9432
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1968 - accuracy: 0.9445 - val_loss: 0.1898 - val_accuracy: 0.9459
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1843 - accuracy: 0.9481 - val_loss: 0.1785 - val_accuracy: 0.9480
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1732 - accuracy: 0.9506 - val_loss: 0.1697 - val_accuracy: 0.9489
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1635 - accuracy: 0.9539 - val_loss: 0.1629 - val_accuracy: 0.9509
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1629 - accuracy: 0.9509
# loss=0.163
# Accuracy=0.951
